# %% [markdown]
# # Create timeseries for electric vehicles to use as flexibility sources in OPF
# ---

# %% [markdown]
# To use electric vehicles in the OPF, we need to create a time series for the electric vehicle consumption. This is done using the `Consumption` class from the `emobpy` package. The `Consumption` class allows us to define the vehicle model, including its specifications and driving behavior.

# %%
from emobpy import Mobility

# %% [markdown]
# Choose the number of vehicles oyou would like to have in your simulation.

# %%
n_vehicles =  1

# %% [markdown]
# Create timeseries profiles for each of the vehicles

# %%
mobility_profiles = []

for i in range(n_vehicles):
    m = Mobility(config_folder = r'C:\Users\f.nasr\AppData\Local\miniconda3\envs\potpourri_env_neu\Lib\site-packages\emobpy\data\base\config_files')  # Load the mobility profile from the database
    m.set_params(
            name_prefix="BEV"+ str(i+1),
            total_hours= 48, # one week
            time_step_in_hrs=0.25, # 15 minutes
            category="user_defined",
            reference_date="01/01/2020"
            )
    m.set_stats(
            stat_ntrip_path="TripsPerDay.csv",
            stat_dest_path="DepartureDestinationTrip.csv",
            stat_km_duration_path="DistanceDurationTrip.csv",
            )
    m.set_rules(rule_key="user_defined") # see /config_files/rules.yml, it contains a dictionary

    m.run()
    mobility_profiles.append(m.timeseries)
# Out:
# New profile running: BEV1_W2_3c0bd
# Progress: 100% [7 / 7] days
# Profile done: BEV1_W2_3c0bd
# Elapsed time (min): 0.0
# C:\Users\f.nasr\AppData\Local\miniconda3\envs\potpourri_env_neu\Lib\site-packages\emobpy\mobility.py:247: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[list([3.885e-05, 3.885e-05]) list([3.885e-05, 3.885e-05])
#  list([3.885e-05, 3.885e-05]) list([3.885e-05, 3.885e-05])
#  list([3.885e-05, 3.885e-05]) list([3.885e-05, 3.885e-05])
#  list([3.885e-05, 3.885e-05]) list([3.885e-05, 3.885e-05])
#  list([3.885e-05, 3.885e-05]) list([3.885e-05, 3.885e-05])
#  list([3.885e-05, 3.885e-05]) list([3.885e-05, 3.885e-05])
#  list([0.00027195, 0.00027195]) list([0.00027195, 0.00027195])
#  list([0.00027195, 0.00027195]) list([0.00027195, 0.00027195])
#  list([0.00027195, 0.00027195]) list([0.00027195, 0.00027195])
#  list([0.00244775, 0.00244775]) list([0.00244775, 0.00244775])
#  list([0.00244775, 0.00244775]) list([0.00244775, 0.00244775])
#  list([0.0029917, 0.0029917]) list([0.0029917, 0.0029917])
#  list([0.0029917, 0.0029917]) list([0.0029917, 0.0029917])
#  list([0.0029917, 0.0029917]) list([0.0029917, 0.0029917])
#  list([0.00217575, 0.00217575]) list([0.00217575, 0.00217575])
#  list([0.00217575, 0.00217575]) list([0.00217575, 0.00217575])
#  list([0.00217575, 0.00217575]) list([0.00217575, 0.00217575])
#  list([0.0014505, 0.0014505]) list([0.0014505, 0.0014505])
#  list([0.0014505, 0.0014505]) list([0.0014505, 0.0014505])
#  list([0.0014505, 0.0014505]) list([0.0014505, 0.0014505])
#  list([0.0004533, 0.0004533]) list([0.0004533, 0.0004533])
#  list([0.0004533, 0.0004533]) list([0.0004533, 0.0004533])
#  list([0.0004533, 0.0004533]) list([0.0004533, 0.0004533])
#  list([3.885e-05, 3.885e-05]) list([3.885e-05, 3.885e-05])
#  list([3.485e-05, 3.485e-05]) list([3.485e-05, 3.485e-05])
#  list([3.485e-05, 3.485e-05]) list([3.485e-05, 3.485e-05])
#  list([3.485e-05, 3.485e-05]) list([3.485e-05, 3.485e-05])
#  list([3.485e-05, 3.485e-05]) list([3.485e-05, 3.485e-05])
#  list([3.485e-05, 3.485e-05]) list([3.485e-05, 3.485e-05])
#  list([3.485e-05, 3.485e-05]) list([3.485e-05, 3.485e-05])
#  list([0.00016255, 0.00016255]) list([0.00016255, 0.00016255])
#  list([0.00016255, 0.00016255]) list([0.00016255, 0.00016255])
#  list([0.00016255, 0.00016255]) list([0.00016255, 0.00016255])
#  list([0.00182855, 0.00182855]) list([0.00182855, 0.00182855])
#  list([0.00182855, 0.00182855]) list([0.00182855, 0.00182855])
#  list([0.0023568, 0.0023568]) list([0.0023568, 0.0023568])
#  list([0.0023568, 0.0023568]) list([0.0023568, 0.0023568])
#  list([0.0023568, 0.0023568]) list([0.0023568, 0.0023568])
#  list([0.00219425, 0.00219425]) list([0.00219425, 0.00219425])
#  list([0.00219425, 0.00219425]) list([0.00219425, 0.00219425])
#  list([0.00219425, 0.00219425]) list([0.00219425, 0.00219425])
#  list([0.0015441, 0.0015441]) list([0.0015441, 0.0015441])
#  list([0.0015441, 0.0015441]) list([0.0015441, 0.0015441])
#  list([0.0015441, 0.0015441]) list([0.0015441, 0.0015441])
#  list([0.00040635, 0.00040635]) list([0.00040635, 0.00040635])
#  list([0.00040635, 0.00040635]) list([0.00040635, 0.00040635])
#  list([0.00040635, 0.00040635]) list([0.00040635, 0.00040635])
#  list([3.485e-05, 3.485e-05]) list([3.485e-05, 3.485e-05])
#  list([6.005e-05, 6.005e-05]) list([6.005e-05, 6.005e-05])
#  list([6.005e-05, 6.005e-05]) list([6.005e-05, 6.005e-05])
#  list([6.005e-05, 6.005e-05]) list([6.005e-05, 6.005e-05])
#  list([6.005e-05, 6.005e-05]) list([6.005e-05, 6.005e-05])
#  list([6.005e-05, 6.005e-05]) list([6.005e-05, 6.005e-05])
#  list([6.005e-05, 6.005e-05]) list([6.005e-05, 6.005e-05])
#  list([0.00084245, 0.00084245]) list([0.00084245, 0.00084245])
#  list([0.00084245, 0.00084245]) list([0.00084245, 0.00084245])
#  list([0.00084245, 0.00084245]) list([0.00084245, 0.00084245])
#  list([0.00548035, 0.00548035]) list([0.00548035, 0.00548035])
#  list([0.00548035, 0.00548035]) list([0.00548035, 0.00548035])
#  list([0.0046379, 0.0046379]) list([0.0046379, 0.0046379])
#  list([0.0046379, 0.0046379]) list([0.0046379, 0.0046379])
#  list([0.0046379, 0.0046379]) list([0.0046379, 0.0046379])
#  list([0.00309135, 0.00309135]) list([0.00309135, 0.00309135])
#  list([0.00309135, 0.00309135]) list([0.00309135, 0.00309135])
#  list([0.00309135, 0.00309135]) list([0.00309135, 0.00309135])
#  list([0.00154655, 0.00154655]) list([0.00154655, 0.00154655])
#  list([0.00154655, 0.00154655]) list([0.00154655, 0.00154655])
#  list([0.00154655, 0.00154655]) list([0.00154655, 0.00154655])
#  list([0.0002802, 0.0002802]) list([0.0002802, 0.0002802])
#  list([0.0002802, 0.0002802]) list([0.0002802, 0.0002802])
#  list([0.0002802, 0.0002802]) list([0.0002802, 0.0002802])
#  list([6.005e-05, 6.005e-05]) list([6.005e-05, 6.005e-05])]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, j] = df[j].apply(make_list, factor=factor)
# C:\Users\f.nasr\AppData\Local\miniconda3\envs\potpourri_env_neu\Lib\site-packages\emobpy\mobility.py:247: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[list([7.485e-05, 7.485e-05]) list([7.485e-05, 7.485e-05])
#  list([7.485e-05, 7.485e-05]) list([7.485e-05, 7.485e-05])
#  list([7.485e-05, 7.485e-05]) list([7.485e-05, 7.485e-05])
#  list([7.485e-05, 7.485e-05]) list([7.485e-05, 7.485e-05])
#  list([7.485e-05, 7.485e-05]) list([7.485e-05, 7.485e-05])
#  list([7.485e-05, 7.485e-05]) list([7.485e-05, 7.485e-05])
#  list([0.00013105, 0.00013105]) list([0.00013105, 0.00013105])
#  list([0.00013105, 0.00013105]) list([0.00013105, 0.00013105])
#  list([0.00013105, 0.00013105]) list([0.00013105, 0.00013105])
#  list([0.0008517, 0.0008517]) list([0.0008517, 0.0008517])
#  list([0.0008517, 0.0008517]) list([0.0008517, 0.0008517])
#  list([0.00122295, 0.00122295]) list([0.00122295, 0.00122295])
#  list([0.00122295, 0.00122295]) list([0.00122295, 0.00122295])
#  list([0.00122295, 0.00122295]) list([0.00122295, 0.00122295])
#  list([0.00100455, 0.00100455]) list([0.00100455, 0.00100455])
#  list([0.00100455, 0.00100455]) list([0.00100455, 0.00100455])
#  list([0.00100455, 0.00100455]) list([0.00100455, 0.00100455])
#  list([0.0009172, 0.0009172]) list([0.0009172, 0.0009172])
#  list([0.0009172, 0.0009172]) list([0.0009172, 0.0009172])
#  list([0.0009172, 0.0009172]) list([0.0009172, 0.0009172])
#  list([0.0003494, 0.0003494]) list([0.0003494, 0.0003494])
#  list([0.0003494, 0.0003494]) list([0.0003494, 0.0003494])
#  list([0.0003494, 0.0003494]) list([0.0003494, 0.0003494])
#  list([7.485e-05, 7.485e-05]) list([7.485e-05, 7.485e-05])
#  list([3.545e-05, 3.545e-05]) list([3.545e-05, 3.545e-05])
#  list([3.545e-05, 3.545e-05]) list([3.545e-05, 3.545e-05])
#  list([3.545e-05, 3.545e-05]) list([3.545e-05, 3.545e-05])
#  list([3.545e-05, 3.545e-05]) list([3.545e-05, 3.545e-05])
#  list([3.545e-05, 3.545e-05]) list([3.545e-05, 3.545e-05])
#  list([3.545e-05, 3.545e-05]) list([3.545e-05, 3.545e-05])
#  list([8.27e-05, 8.27e-05]) list([8.27e-05, 8.27e-05])
#  list([8.27e-05, 8.27e-05]) list([8.27e-05, 8.27e-05])
#  list([8.27e-05, 8.27e-05]) list([8.27e-05, 8.27e-05])
#  list([0.0007441, 0.0007441]) list([0.0007441, 0.0007441])
#  list([0.0007441, 0.0007441]) list([0.0007441, 0.0007441])
#  list([0.0010748, 0.0010748]) list([0.0010748, 0.0010748])
#  list([0.0010748, 0.0010748]) list([0.0010748, 0.0010748])
#  list([0.0010748, 0.0010748]) list([0.0010748, 0.0010748])
#  list([0.0011988, 0.0011988]) list([0.0011988, 0.0011988])
#  list([0.0011988, 0.0011988]) list([0.0011988, 0.0011988])
#  list([0.0011988, 0.0011988]) list([0.0011988, 0.0011988])
#  list([0.0008681, 0.0008681]) list([0.0008681, 0.0008681])
#  list([0.0008681, 0.0008681]) list([0.0008681, 0.0008681])
#  list([0.0008681, 0.0008681]) list([0.0008681, 0.0008681])
#  list([0.00037205, 0.00037205]) list([0.00037205, 0.00037205])
#  list([0.00037205, 0.00037205]) list([0.00037205, 0.00037205])
#  list([0.00037205, 0.00037205]) list([0.00037205, 0.00037205])
#  list([3.545e-05, 3.545e-05]) list([3.545e-05, 3.545e-05])
#  list([2.77e-05, 2.77e-05]) list([2.77e-05, 2.77e-05])
#  list([2.77e-05, 2.77e-05]) list([2.77e-05, 2.77e-05])
#  list([2.77e-05, 2.77e-05]) list([2.77e-05, 2.77e-05])
#  list([2.77e-05, 2.77e-05]) list([2.77e-05, 2.77e-05])
#  list([2.77e-05, 2.77e-05]) list([2.77e-05, 2.77e-05])
#  list([2.77e-05, 2.77e-05]) list([2.77e-05, 2.77e-05])
#  list([0.00060895, 0.00060895]) list([0.00060895, 0.00060895])
#  list([0.00060895, 0.00060895]) list([0.00060895, 0.00060895])
#  list([0.00060895, 0.00060895]) list([0.00060895, 0.00060895])
#  list([0.0010589, 0.0010589]) list([0.0010589, 0.0010589])
#  list([0.0010589, 0.0010589]) list([0.0010589, 0.0010589])
#  list([0.00044905, 0.00044905]) list([0.00044905, 0.00044905])
#  list([0.00044905, 0.00044905]) list([0.00044905, 0.00044905])
#  list([0.00044905, 0.00044905]) list([0.00044905, 0.00044905])
#  list([0.0009628, 0.0009628]) list([0.0009628, 0.0009628])
#  list([0.0009628, 0.0009628]) list([0.0009628, 0.0009628])
#  list([0.0009628, 0.0009628]) list([0.0009628, 0.0009628])
#  list([0.00035205, 0.00035205]) list([0.00035205, 0.00035205])
#  list([0.00035205, 0.00035205]) list([0.00035205, 0.00035205])
#  list([0.00035205, 0.00035205]) list([0.00035205, 0.00035205])
#  list([6.465e-05, 6.465e-05]) list([6.465e-05, 6.465e-05])
#  list([6.465e-05, 6.465e-05]) list([6.465e-05, 6.465e-05])
#  list([6.465e-05, 6.465e-05]) list([6.465e-05, 6.465e-05])
#  list([2.77e-05, 2.77e-05]) list([2.77e-05, 2.77e-05])]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, j] = df[j].apply(make_list, factor=factor)
# C:\Users\f.nasr\AppData\Local\miniconda3\envs\potpourri_env_neu\Lib\site-packages\emobpy\mobility.py:247: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[list([0.00110795, 0.00110795]) list([0.00110795, 0.00110795])
#  list([0.00110795, 0.00110795]) list([0.00110795, 0.00110795])
#  list([0.00110795, 0.00110795]) list([0.00110795, 0.00110795])
#  list([0.00110795, 0.00110795]) list([0.00110795, 0.00110795])
#  list([0.00110795, 0.00110795]) list([0.00110795, 0.00110795])
#  list([0.00110795, 0.00110795]) list([0.00110795, 0.00110795])
#  list([0.0006463, 0.0006463]) list([0.0006463, 0.0006463])
#  list([0.0006463, 0.0006463]) list([0.0006463, 0.0006463])
#  list([0.0006463, 0.0006463]) list([0.0006463, 0.0006463])
#  list([0.0038778, 0.0038778]) list([0.0038778, 0.0038778])
#  list([0.0038778, 0.0038778]) list([0.0038778, 0.0038778])
#  list([0.00775565, 0.00775565]) list([0.00775565, 0.00775565])
#  list([0.00775565, 0.00775565]) list([0.00775565, 0.00775565])
#  list([0.00775565, 0.00775565]) list([0.00775565, 0.00775565])
#  list([0.00646305, 0.00646305]) list([0.00646305, 0.00646305])
#  list([0.00646305, 0.00646305]) list([0.00646305, 0.00646305])
#  list([0.00646305, 0.00646305]) list([0.00646305, 0.00646305])
#  list([0.0080788, 0.0080788]) list([0.0080788, 0.0080788])
#  list([0.0080788, 0.0080788]) list([0.0080788, 0.0080788])
#  list([0.0080788, 0.0080788]) list([0.0080788, 0.0080788])
#  list([0.00420095, 0.00420095]) list([0.00420095, 0.00420095])
#  list([0.00420095, 0.00420095]) list([0.00420095, 0.00420095])
#  list([0.00420095, 0.00420095]) list([0.00420095, 0.00420095])
#  list([0.00110795, 0.00110795]) list([0.00110795, 0.00110795])
#  list([0.0007331, 0.0007331]) list([0.0007331, 0.0007331])
#  list([0.0007331, 0.0007331]) list([0.0007331, 0.0007331])
#  list([0.0007331, 0.0007331]) list([0.0007331, 0.0007331])
#  list([0.0007331, 0.0007331]) list([0.0007331, 0.0007331])
#  list([0.0007331, 0.0007331]) list([0.0007331, 0.0007331])
#  list([0.0007331, 0.0007331]) list([0.0007331, 0.0007331])
#  list([0.0003421, 0.0003421]) list([0.0003421, 0.0003421])
#  list([0.0003421, 0.0003421]) list([0.0003421, 0.0003421])
#  list([0.0003421, 0.0003421]) list([0.0003421, 0.0003421])
#  list([0.00256585, 0.00256585]) list([0.00256585, 0.00256585])
#  list([0.00256585, 0.00256585]) list([0.00256585, 0.00256585])
#  list([0.00615805, 0.00615805]) list([0.00615805, 0.00615805])
#  list([0.00615805, 0.00615805]) list([0.00615805, 0.00615805])
#  list([0.00615805, 0.00615805]) list([0.00615805, 0.00615805])
#  list([0.0075265, 0.0075265]) list([0.0075265, 0.0075265])
#  list([0.0075265, 0.0075265]) list([0.0075265, 0.0075265])
#  list([0.0075265, 0.0075265]) list([0.0075265, 0.0075265])
#  list([0.01128975, 0.01128975]) list([0.01128975, 0.01128975])
#  list([0.01128975, 0.01128975]) list([0.01128975, 0.01128975])
#  list([0.01128975, 0.01128975]) list([0.01128975, 0.01128975])
#  list([0.00547385, 0.00547385]) list([0.00547385, 0.00547385])
#  list([0.00547385, 0.00547385]) list([0.00547385, 0.00547385])
#  list([0.00547385, 0.00547385]) list([0.00547385, 0.00547385])
#  list([0.0007331, 0.0007331]) list([0.0007331, 0.0007331])
#  list([0.0004211, 0.0004211]) list([0.0004211, 0.0004211])
#  list([0.0004211, 0.0004211]) list([0.0004211, 0.0004211])
#  list([0.0004211, 0.0004211]) list([0.0004211, 0.0004211])
#  list([0.0004211, 0.0004211]) list([0.0004211, 0.0004211])
#  list([0.0004211, 0.0004211]) list([0.0004211, 0.0004211])
#  list([0.0004211, 0.0004211]) list([0.0004211, 0.0004211])
#  list([0.0003269, 0.0003269]) list([0.0003269, 0.0003269])
#  list([0.0003269, 0.0003269]) list([0.0003269, 0.0003269])
#  list([0.0003269, 0.0003269]) list([0.0003269, 0.0003269])
#  list([0.00490915, 0.00490915]) list([0.00490915, 0.00490915])
#  list([0.00490915, 0.00490915]) list([0.00490915, 0.00490915])
#  list([0.0098201, 0.0098201]) list([0.0098201, 0.0098201])
#  list([0.0098201, 0.0098201]) list([0.0098201, 0.0098201])
#  list([0.0098201, 0.0098201]) list([0.0098201, 0.0098201])
#  list([0.0075281, 0.0075281]) list([0.0075281, 0.0075281])
#  list([0.0075281, 0.0075281]) list([0.0075281, 0.0075281])
#  list([0.0075281, 0.0075281]) list([0.0075281, 0.0075281])
#  list([0.0075281, 0.0075281]) list([0.0075281, 0.0075281])
#  list([0.0075281, 0.0075281]) list([0.0075281, 0.0075281])
#  list([0.0075281, 0.0075281]) list([0.0075281, 0.0075281])
#  list([0.00294585, 0.00294585]) list([0.00294585, 0.00294585])
#  list([0.00294585, 0.00294585]) list([0.00294585, 0.00294585])
#  list([0.00294585, 0.00294585]) list([0.00294585, 0.00294585])
#  list([0.0004211, 0.0004211]) list([0.0004211, 0.0004211])]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, j] = df[j].apply(make_list, factor=factor)
# C:\Users\f.nasr\AppData\Local\miniconda3\envs\potpourri_env_neu\Lib\site-packages\emobpy\mobility.py:247: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[list([0.0002731, 0.0002731]) list([0.0002731, 0.0002731])
#  list([0.0002731, 0.0002731]) list([0.0002731, 0.0002731])
#  list([0.0002731, 0.0002731]) list([0.0002731, 0.0002731])
#  list([0.0002731, 0.0002731]) list([0.0002731, 0.0002731])
#  list([0.0002731, 0.0002731]) list([0.0002731, 0.0002731])
#  list([0.0002731, 0.0002731]) list([0.0002731, 0.0002731])
#  list([0.00063725, 0.00063725]) list([0.00063725, 0.00063725])
#  list([0.00063725, 0.00063725]) list([0.00063725, 0.00063725])
#  list([0.00063725, 0.00063725]) list([0.00063725, 0.00063725])
#  list([0.003505, 0.003505]) list([0.003505, 0.003505])
#  list([0.003505, 0.003505]) list([0.003505, 0.003505])
#  list([0.0044609, 0.0044609]) list([0.0044609, 0.0044609])
#  list([0.0044609, 0.0044609]) list([0.0044609, 0.0044609])
#  list([0.0044609, 0.0044609]) list([0.0044609, 0.0044609])
#  list([0.00594785, 0.00594785]) list([0.00594785, 0.00594785])
#  list([0.00594785, 0.00594785]) list([0.00594785, 0.00594785])
#  list([0.00594785, 0.00594785]) list([0.00594785, 0.00594785])
#  list([0.00509815, 0.00509815]) list([0.00509815, 0.00509815])
#  list([0.00509815, 0.00509815]) list([0.00509815, 0.00509815])
#  list([0.00509815, 0.00509815]) list([0.00509815, 0.00509815])
#  list([0.00212425, 0.00212425]) list([0.00212425, 0.00212425])
#  list([0.00212425, 0.00212425]) list([0.00212425, 0.00212425])
#  list([0.00212425, 0.00212425]) list([0.00212425, 0.00212425])
#  list([0.0002731, 0.0002731]) list([0.0002731, 0.0002731])
#  list([0.0001466, 0.0001466]) list([0.0001466, 0.0001466])
#  list([0.0001466, 0.0001466]) list([0.0001466, 0.0001466])
#  list([0.0001466, 0.0001466]) list([0.0001466, 0.0001466])
#  list([0.0001466, 0.0001466]) list([0.0001466, 0.0001466])
#  list([0.0001466, 0.0001466]) list([0.0001466, 0.0001466])
#  list([0.0001466, 0.0001466]) list([0.0001466, 0.0001466])
#  list([0.00068405, 0.00068405]) list([0.00068405, 0.00068405])
#  list([0.00068405, 0.00068405]) list([0.00068405, 0.00068405])
#  list([0.00068405, 0.00068405]) list([0.00068405, 0.00068405])
#  list([0.00615625, 0.00615625]) list([0.00615625, 0.00615625])
#  list([0.00615625, 0.00615625]) list([0.00615625, 0.00615625])
#  list([0.00991835, 0.00991835]) list([0.00991835, 0.00991835])
#  list([0.00991835, 0.00991835]) list([0.00991835, 0.00991835])
#  list([0.00991835, 0.00991835]) list([0.00991835, 0.00991835])
#  list([0.01162845, 0.01162845]) list([0.01162845, 0.01162845])
#  list([0.01162845, 0.01162845]) list([0.01162845, 0.01162845])
#  list([0.01162845, 0.01162845]) list([0.01162845, 0.01162845])
#  list([0.0058142, 0.0058142]) list([0.0058142, 0.0058142])
#  list([0.0058142, 0.0058142]) list([0.0058142, 0.0058142])
#  list([0.0058142, 0.0058142]) list([0.0058142, 0.0058142])
#  list([0.00171005, 0.00171005]) list([0.00171005, 0.00171005])
#  list([0.00171005, 0.00171005]) list([0.00171005, 0.00171005])
#  list([0.00171005, 0.00171005]) list([0.00171005, 0.00171005])
#  list([0.0001466, 0.0001466]) list([0.0001466, 0.0001466])
#  list([0.00014395, 0.00014395]) list([0.00014395, 0.00014395])
#  list([0.00014395, 0.00014395]) list([0.00014395, 0.00014395])
#  list([0.00014395, 0.00014395]) list([0.00014395, 0.00014395])
#  list([0.00014395, 0.00014395]) list([0.00014395, 0.00014395])
#  list([0.00014395, 0.00014395]) list([0.00014395, 0.00014395])
#  list([0.00014395, 0.00014395]) list([0.00014395, 0.00014395])
#  list([0.0006718, 0.0006718]) list([0.0006718, 0.0006718])
#  list([0.0006718, 0.0006718]) list([0.0006718, 0.0006718])
#  list([0.0006718, 0.0006718]) list([0.0006718, 0.0006718])
#  list([0.00352425, 0.00352425]) list([0.00352425, 0.00352425])
#  list([0.00352425, 0.00352425]) list([0.00352425, 0.00352425])
#  list([0.00386015, 0.00386015]) list([0.00386015, 0.00386015])
#  list([0.00386015, 0.00386015]) list([0.00386015, 0.00386015])
#  list([0.00386015, 0.00386015]) list([0.00386015, 0.00386015])
#  list([0.00520195, 0.00520195]) list([0.00520195, 0.00520195])
#  list([0.00520195, 0.00520195]) list([0.00520195, 0.00520195])
#  list([0.00520195, 0.00520195]) list([0.00520195, 0.00520195])
#  list([0.0033572, 0.0033572]) list([0.0033572, 0.0033572])
#  list([0.0033572, 0.0033572]) list([0.0033572, 0.0033572])
#  list([0.0033572, 0.0033572]) list([0.0033572, 0.0033572])
#  list([0.0010077, 0.0010077]) list([0.0010077, 0.0010077])
#  list([0.0010077, 0.0010077]) list([0.0010077, 0.0010077])
#  list([0.0010077, 0.0010077]) list([0.0010077, 0.0010077])
#  list([0.00014395, 0.00014395]) list([0.00014395, 0.00014395])]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, j] = df[j].apply(make_list, factor=factor)
# C:\Users\f.nasr\AppData\Local\miniconda3\envs\potpourri_env_neu\Lib\site-packages\emobpy\mobility.py:247: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0])
#  list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0])
#  list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0])
#  list([0.00098055, 0.00098055]) list([0.00098055, 0.00098055])
#  list([0.00098055, 0.00098055]) list([0.00098055, 0.00098055])
#  list([0.00098055, 0.00098055]) list([0.00098055, 0.00098055])
#  list([0.00612845, 0.00612845]) list([0.00612845, 0.00612845])
#  list([0.00612845, 0.00612845]) list([0.00612845, 0.00612845])
#  list([0.00604675, 0.00604675]) list([0.00604675, 0.00604675])
#  list([0.00604675, 0.00604675]) list([0.00604675, 0.00604675])
#  list([0.00604675, 0.00604675]) list([0.00604675, 0.00604675])
#  list([0.00294165, 0.00294165]) list([0.00294165, 0.00294165])
#  list([0.00294165, 0.00294165]) list([0.00294165, 0.00294165])
#  list([0.00294165, 0.00294165]) list([0.00294165, 0.00294165])
#  list([0.0019611, 0.0019611]) list([0.0019611, 0.0019611])
#  list([0.0019611, 0.0019611]) list([0.0019611, 0.0019611])
#  list([0.0019611, 0.0019611]) list([0.0019611, 0.0019611])
#  list([0.00032685, 0.00032685]) list([0.00032685, 0.00032685])
#  list([0.00032685, 0.00032685]) list([0.00032685, 0.00032685])
#  list([0.00032685, 0.00032685]) list([0.00032685, 0.00032685])
#  list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0])
#  list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0])
#  list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0])
#  list([0.0, 0.0]) list([0.0, 0.0]) list([0.0002781, 0.0002781])
#  list([0.0002781, 0.0002781]) list([0.0002781, 0.0002781])
#  list([0.0002781, 0.0002781]) list([0.0002781, 0.0002781])
#  list([0.0002781, 0.0002781]) list([0.001919, 0.001919])
#  list([0.001919, 0.001919]) list([0.001919, 0.001919])
#  list([0.001919, 0.001919]) list([0.00058405, 0.00058405])
#  list([0.00058405, 0.00058405]) list([0.00058405, 0.00058405])
#  list([0.00058405, 0.00058405]) list([0.00058405, 0.00058405])
#  list([0.00058405, 0.00058405]) list([0.0004172, 0.0004172])
#  list([0.0004172, 0.0004172]) list([0.0004172, 0.0004172])
#  list([0.0004172, 0.0004172]) list([0.0004172, 0.0004172])
#  list([0.0004172, 0.0004172]) list([0.00016685, 0.00016685])
#  list([0.00016685, 0.00016685]) list([0.00016685, 0.00016685])
#  list([0.00016685, 0.00016685]) list([0.00016685, 0.00016685])
#  list([0.00016685, 0.00016685]) list([5.56e-05, 5.56e-05])
#  list([5.56e-05, 5.56e-05]) list([5.56e-05, 5.56e-05])
#  list([5.56e-05, 5.56e-05]) list([5.56e-05, 5.56e-05])
#  list([5.56e-05, 5.56e-05]) list([0.0, 0.0]) list([0.0, 0.0])
#  list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0])
#  list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0])
#  list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0]) list([0.0, 0.0])
#  list([0.00050295, 0.00050295]) list([0.00050295, 0.00050295])
#  list([0.00050295, 0.00050295]) list([0.00050295, 0.00050295])
#  list([0.00050295, 0.00050295]) list([0.00050295, 0.00050295])
#  list([0.0072829, 0.0072829]) list([0.0072829, 0.0072829])
#  list([0.0072829, 0.0072829]) list([0.0072829, 0.0072829])
#  list([0.0060282, 0.0060282]) list([0.0060282, 0.0060282])
#  list([0.0060282, 0.0060282]) list([0.0060282, 0.0060282])
#  list([0.0060282, 0.0060282]) list([0.0060282, 0.0060282])
#  list([0.0030141, 0.0030141]) list([0.0030141, 0.0030141])
#  list([0.0030141, 0.0030141]) list([0.0030141, 0.0030141])
#  list([0.0030141, 0.0030141]) list([0.0030141, 0.0030141])
#  list([0.00201, 0.00201]) list([0.00201, 0.00201])
#  list([0.00201, 0.00201]) list([0.00201, 0.00201])
#  list([0.00201, 0.00201]) list([0.00201, 0.00201])
#  list([0.0003341, 0.0003341]) list([0.0003341, 0.0003341])
#  list([0.0003341, 0.0003341]) list([0.0003341, 0.0003341])
#  list([0.0003341, 0.0003341]) list([0.0003341, 0.0003341])
#  list([0.0, 0.0]) list([0.0, 0.0])]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, j] = df[j].apply(make_list, factor=factor)
# C:\Users\f.nasr\AppData\Local\miniconda3\envs\potpourri_env_neu\Lib\site-packages\emobpy\mobility.py:248: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[list([24.0, 24.25]) list([24.5, 24.75]) list([25.0, 25.25])
#  list([25.5, 25.75]) list([26.0, 26.25]) list([26.5, 26.75])
#  list([3.0, 3.25]) list([3.5, 3.75]) list([4.0, 4.25]) list([4.5, 4.75])
#  list([5.0, 5.25]) list([5.5, 5.75]) list([6.0, 6.25]) list([6.5, 6.75])
#  list([7.0, 7.25]) list([7.5, 7.75]) list([8.0, 8.25]) list([8.5, 8.75])
#  list([9.0, 9.25]) list([9.5, 9.75]) list([10.0, 10.25])
#  list([10.5, 10.75]) list([11.0, 11.25]) list([11.5, 11.75])
#  list([12.0, 12.25]) list([12.5, 12.75]) list([13.0, 13.25])
#  list([13.5, 13.75]) list([14.0, 14.25]) list([14.5, 14.75])
#  list([15.0, 15.25]) list([15.5, 15.75]) list([16.0, 16.25])
#  list([16.5, 16.75]) list([17.0, 17.25]) list([17.5, 17.75])
#  list([18.0, 18.25]) list([18.5, 18.75]) list([19.0, 19.25])
#  list([19.5, 19.75]) list([20.0, 20.25]) list([20.5, 20.75])
#  list([21.0, 21.25]) list([21.5, 21.75]) list([22.0, 22.25])
#  list([22.5, 22.75]) list([23.0, 23.25]) list([23.5, 23.75])
#  list([24.0, 24.25]) list([24.5, 24.75]) list([25.0, 25.25])
#  list([25.5, 25.75]) list([26.0, 26.25]) list([26.5, 26.75])
#  list([3.0, 3.25]) list([3.5, 3.75]) list([4.0, 4.25]) list([4.5, 4.75])
#  list([5.0, 5.25]) list([5.5, 5.75]) list([6.0, 6.25]) list([6.5, 6.75])
#  list([7.0, 7.25]) list([7.5, 7.75]) list([8.0, 8.25]) list([8.5, 8.75])
#  list([9.0, 9.25]) list([9.5, 9.75]) list([10.0, 10.25])
#  list([10.5, 10.75]) list([11.0, 11.25]) list([11.5, 11.75])
#  list([12.0, 12.25]) list([12.5, 12.75]) list([13.0, 13.25])
#  list([13.5, 13.75]) list([14.0, 14.25]) list([14.5, 14.75])
#  list([15.0, 15.25]) list([15.5, 15.75]) list([16.0, 16.25])
#  list([16.5, 16.75]) list([17.0, 17.25]) list([17.5, 17.75])
#  list([18.0, 18.25]) list([18.5, 18.75]) list([19.0, 19.25])
#  list([19.5, 19.75]) list([20.0, 20.25]) list([20.5, 20.75])
#  list([21.0, 21.25]) list([21.5, 21.75]) list([22.0, 22.25])
#  list([22.5, 22.75]) list([23.0, 23.25]) list([23.5, 23.75])
#  list([24.0, 24.25]) list([24.5, 24.75]) list([25.0, 25.25])
#  list([25.5, 25.75]) list([26.0, 26.25]) list([26.5, 26.75])
#  list([3.0, 3.25]) list([3.5, 3.75]) list([4.0, 4.25]) list([4.5, 4.75])
#  list([5.0, 5.25]) list([5.5, 5.75]) list([6.0, 6.25]) list([6.5, 6.75])
#  list([7.0, 7.25]) list([7.5, 7.75]) list([8.0, 8.25]) list([8.5, 8.75])
#  list([9.0, 9.25]) list([9.5, 9.75]) list([10.0, 10.25])
#  list([10.5, 10.75]) list([11.0, 11.25]) list([11.5, 11.75])
#  list([12.0, 12.25]) list([12.5, 12.75]) list([13.0, 13.25])
#  list([13.5, 13.75]) list([14.0, 14.25]) list([14.5, 14.75])
#  list([15.0, 15.25]) list([15.5, 15.75]) list([16.0, 16.25])
#  list([16.5, 16.75]) list([17.0, 17.25]) list([17.5, 17.75])
#  list([18.0, 18.25]) list([18.5, 18.75]) list([19.0, 19.25])
#  list([19.5, 19.75]) list([20.0, 20.25]) list([20.5, 20.75])
#  list([21.0, 21.25]) list([21.5, 21.75]) list([22.0, 22.25])
#  list([22.5, 22.75]) list([23.0, 23.25]) list([23.5, 23.75])]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, "time"] = df["time"].apply(
# C:\Users\f.nasr\AppData\Local\miniconda3\envs\potpourri_env_neu\Lib\site-packages\emobpy\mobility.py:944: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   self.rp.loc[:, self.repeats] = self.rp[self.repeats].fillna(method="ffill")
# C:\Users\f.nasr\AppData\Local\miniconda3\envs\potpourri_env_neu\Lib\site-packages\emobpy\mobility.py:944: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.rp.loc[:, self.repeats] = self.rp[self.repeats].fillna(method="ffill")
# C:\Users\f.nasr\AppData\Local\miniconda3\envs\potpourri_env_neu\Lib\site-packages\emobpy\tools.py:38: FutureWarning: Non-integer 'periods' in pd.date_range, pd.timedelta_range, pd.period_range, and pd.interval_range are deprecated and will raise in a future version.
#   drange = pd.date_range(start_date, periods=totalrows, freq=freq)
